# %%
import pandas as pd

# %%
#Series

values = [10, 20, 30, 40, 50]
s = pd.Series(values, index = ['a', 'b', 'c', 'd', 'e'])
print(s)

#Data Frames

df = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'City': ['New York', 'San Francisco', 'Los Angeles']
})
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64

# %%
df = df.set_index('Name')
df
# Out:
#          Age           City
# Name
# Alice     25       New York
# Bob       30  San Francisco
# Charlie   35    Los Angeles

# %%
df1 = pd.DataFrame({
    'a': [1, 2, 3],
}, index = [0,1,2])

df2 = pd.DataFrame({
    'b': [10, 20, 30]
}, index = [1,2,0])

df1 * df2
# Out:
#     a   b
# 0 NaN NaN
# 1 NaN NaN
# 2 NaN NaN

# %%
df = df.reset_index()
df
# Out:
#       Name  Age           City
# 0    Alice   25       New York
# 1      Bob   30  San Francisco
# 2  Charlie   35    Los Angeles

# %%
df.to_csv('mydata.csv', index = None)

# %%
pd.read_csv('mydata.csv', index_col = 1)
# Out:
#         Name           City
# Age
# 25     Alice       New York
# 30       Bob  San Francisco
# 35   Charlie    Los Angeles

# %%
df.to_json('mydata.json')

# %% [markdown]
# Data Exploration Functions

# %%
import matplotlib.pyplot as plt #for plots
from sklearn.datasets import fetch_california_housing
df = fetch_california_housing(as_frame=True).frame
df.tail() #last five
#df.head() first five
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  MedHouseVal
# 20635    -121.09        0.781
# 20636    -121.21        0.771
# 20637    -121.22        0.923
# 20638    -121.32        0.847
# 20639    -121.24        0.894

# %%
df.sample(5) #Random sample
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 19887  2.1731      29.0  5.086957   1.003106       942.0  2.925466     36.29
# 3600   4.5167      26.0  5.259386   0.977816      1590.0  2.713311     34.23
# 15445  4.5764      18.0  6.777778   1.096774       830.0  2.974910     33.19
# 5145   1.5303      40.0  4.949664   1.164430      1222.0  4.100671     33.96
# 13193  3.8586      34.0  5.385126   0.981408      2470.0  3.280212     34.07
#
#        Longitude  MedHouseVal
# 19887    -119.12        0.662
# 3600     -118.50        3.190
# 15445    -117.25        2.070
# 5145     -118.26        0.953
# 13193    -117.69        1.360

# %%
df.columns #gives columns
# Out:
# Index(['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup',
#        'Latitude', 'Longitude', 'MedHouseVal'],
#       dtype='object')

# %%
list(df.columns) #turns it into list
# Out:
# ['MedInc',
#  'HouseAge',
#  'AveRooms',
#  'AveBedrms',
#  'Population',
#  'AveOccup',
#  'Latitude',
#  'Longitude',
#  'MedHouseVal']

# %%
pd.options.display.max_columns = 5
df
# Out:
#        MedInc  HouseAge  ...  Longitude  MedHouseVal
# 0      8.3252      41.0  ...    -122.23        4.526
# 1      8.3014      21.0  ...    -122.22        3.585
# 2      7.2574      52.0  ...    -122.24        3.521
# 3      5.6431      52.0  ...    -122.25        3.413
# 4      3.8462      52.0  ...    -122.25        3.422
# ...       ...       ...  ...        ...          ...
# 20635  1.5603      25.0  ...    -121.09        0.781
# 20636  2.5568      18.0  ...    -121.21        0.771
# 20637  1.7000      17.0  ...    -121.22        0.923
# 20638  1.8672      18.0  ...    -121.32        0.847
# 20639  2.3886      16.0  ...    -121.24        0.894
#
# [20640 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   MedInc       20640 non-null  float64
#  1   HouseAge     20640 non-null  float64
#  2   AveRooms     20640 non-null  float64
#  3   AveBedrms    20640 non-null  float64
#  4   Population   20640 non-null  float64
#  5   AveOccup     20640 non-null  float64
#  6   Latitude     20640 non-null  float64
#  7   Longitude    20640 non-null  float64
#  8   MedHouseVal  20640 non-null  float64
# dtypes: float64(9)
# memory usage: 1.4 MB

# %% [markdown]
# Statistical Function and Plotting

# %%
df.describe() #summarized info
# Out:
#              MedInc      HouseAge  ...     Longitude   MedHouseVal
# count  20640.000000  20640.000000  ...  20640.000000  20640.000000
# mean       3.870671     28.639486  ...   -119.569704      2.068558
# std        1.899822     12.585558  ...      2.003532      1.153956
# min        0.499900      1.000000  ...   -124.350000      0.149990
# 25%        2.563400     18.000000  ...   -121.800000      1.196000
# 50%        3.534800     29.000000  ...   -118.490000      1.797000
# 75%        4.743250     37.000000  ...   -118.010000      2.647250
# max       15.000100     52.000000  ...   -114.310000      5.000010
#
# [8 rows x 9 columns]

# %%
df.HouseAge #or df['HouseAge']
# Out:
# 0        41.0
# 1        21.0
# 2        52.0
# 3        52.0
# 4        52.0
#          ...
# 20635    25.0
# 20636    18.0
# 20637    17.0
# 20638    18.0
# 20639    16.0
# Name: HouseAge, Length: 20640, dtype: float64

# %%
df['HouseAge'].mean()
# Out:
# np.float64(28.639486434108527)

# %%
df['HouseAge'].median()
# Out:
# 29.0

# %%
df['HouseAge'].std()
# Out:
# 12.585557612111637

# %%
#df['HouseAge'].min()
#df['HouseAge'].count()

# %%
df['HouseAge'].hist()
plt.title('House Age')
plt.show()

# %%
df.hist(figsize = (10,10))
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import yfinance as yf
stock_df = yf.download('AAPL')
# Out:
# /tmp/ipython-input-2185735600.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   stock_df = yf.download('AAPL')
# [*********************100%***********************]  1 of 1 completed

# %%
stock_df
# Out:
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2025-08-25  227.160004  229.300003  226.229996  226.479996   30983100
# 2025-08-26  229.309998  229.490005  224.690002  226.869995   54575100
# 2025-08-27  230.490005  230.899994  228.259995  228.610001   31259500
# 2025-08-28  232.559998  233.410004  229.339996  230.820007   38074700
# 2025-08-29  232.139999  233.380005  231.369995  232.509995   39418400
# 2025-09-02  229.720001  230.850006  226.970001  229.250000   44075600
# 2025-09-03  238.470001  238.850006  234.360001  237.210007   66427800
# 2025-09-04  239.779999  239.899994  236.740005  238.449997   47549400
# 2025-09-05  239.690002  241.320007  238.490005  240.000000   54870400
# 2025-09-08  237.880005  240.149994  236.339996  239.300003   48999500
# 2025-09-09  234.350006  238.779999  233.360001  237.000000   66313900
# ...

# %%
stock_df.Close.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
stock_df.hist()
# Out:
# array([[<Axes: title={'center': "('Close', 'AAPL')"}>,
#         <Axes: title={'center': "('High', 'AAPL')"}>],
#        [<Axes: title={'center': "('Low', 'AAPL')"}>,
#         <Axes: title={'center': "('Open', 'AAPL')"}>],
#        [<Axes: title={'center': "('Volume', 'AAPL')"}>, <Axes: >]],
#       dtype=object)

# %%
df = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'City': ['New York', 'San Francisco', 'Los Angeles']
})

# %%
df
# Out:
#       Name  Age           City
# 0    Alice   25       New York
# 1      Bob   30  San Francisco
# 2  Charlie   35    Los Angeles

# %%
df.loc['Alice', 'Age']
# Out:
# np.int64(25)

# %%
df.iloc[1]
# Out:
# Age                30
# City    San Francisco
# Name: Bob, dtype: object

# %%
df.at['Alice', 'Age']
# Out:
# np.int64(25)

# %%
df.iat[1, 0]
# Out:
# np.int64(30)

# %%
df.at['Alice', 'Age'] = 60
df
# Out:
#          Age           City
# Name
# Alice     60       New York
# Bob       30  San Francisco
# Charlie   35    Los Angeles

# %%
df.loc['Alice'] = [80, 'St. Louis']
df
# Out:
#          Age           City
# Name
# Alice     80      St. Louis
# Bob       30  San Francisco
# Charlie   35    Los Angeles

# %%
df.iloc[0:2]
# Out:
#        Age           City
# Name
# Alice   80      St. Louis
# Bob     30  San Francisco
